# %%
import numpy as np
import cv2
import matplotlib.pyplot as plt

# %%
########################################## key为图像 ##############################
##################### 彩色 ######################
im1 = cv2.imread('key.jpg')
im1 = cv2.GaussianBlur(im1, (9, 9), 0, 0)
im1 = cv2.resize(im1, (350,350))
plt.imshow(im1)
plt.show()
